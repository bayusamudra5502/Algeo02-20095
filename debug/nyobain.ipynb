# %%
import numpy as np
import sklearn.preprocessing
from scipy.linalg.decomp import hessenberg
import math
from PIL import Image
import numpy as np
import io
import time
import cv2

def convertFileToArray(file):
  with Image.open(file) as im:
    return np.array(im.convert("RGBA"))

def convertArrayToIO(array: np.ndarray, mime:str="image/png"):
  im = Image.fromarray(array)
  f = io.BytesIO()

  if mime == "image/png":
    im.save(f, format="PNG")
  else:
    im = im.convert("RGB")
    im.save(f, "JPEG")

  f.seek(0)
  return f

def inspectColor(Im):
    return np.copy(np.int32(np.array(Im[:,:,0]))), \
            np.copy(np.int32(np.array(Im[:,:,1]))), \
            np.copy(np.int32(np.array(Im[:,:,2]))), \
            np.copy(np.int32(np.array(Im[:,:,3]))) 

def inspectcolor2(Im):
    return np.copy(np.array(Im[:,:,0])), np.copy(np.array(Im[:,:,1])), np.copy(np.array(Im[:,:,2])), np.copy(np.array(Im[:,:,3]))

def compress_to_k(A, k):
    # u, sigm, v, rank = build_decom(A)
    u, sigm, v = np.linalg.svd(A)
    rows, cols = A.shape
    sigm = np.pad(np.diag(sigm), ((0,rows),(0,cols)), mode='constant')[0:rows, 0:cols]
    m = np.linalg.matrix_rank(A)
    k = math.floor((k*m)/100)
    return (u[:,:k]@(sigm[:k, :k]@v[:k, :]))


    

# def compress_image(M, k):
#     R, G, B, A = inspectColor(M)
#     R, G, B, A = compress_all(R, G, B, A, k)
#     M = np.uint8((np.dstack((R, G, B, A))))
#     return M

def EigenV(mat, precision = 30):
    _, n = mat.shape
    # MAX_SECTION = n + 3

    # if updater != None:
    #     updater(1/MAX_SECTION)

    H, Q = hessenberg(mat, calc_q=True)
    sub = np.float64(np.copy(np.diag(H,-1)))
    diag = np.float64(np.copy(np.diag(H)))
    sub = np.insert(sub, n-1, 0)
    limit = precision

    # if updater != None:
    #     updater(2/MAX_SECTION)

    for i in range(n):
        # if updater != None and i % 10 == 0:
        #     updater((2+i)/MAX_SECTION)

        niter = 0
        while niter<limit:
            j = i
            while j+1!=n and  np.abs(sub[j]) > 1e-9*(np.abs(diag[j])+np.abs(diag[j+1])):
                j += 1
            if(j==i):
                break
            else:
                niter += 1
                g = (diag[i + 1]-diag[i])/(2*sub[i])
                r = np.hypot(g, 1)
                if(np.abs(g)<1e-9):
                    g = diag[j]-diag[i]+(sub[i]/(g+r))
                else:
                    g = diag[j]-diag[i]+(sub[i]/(g + np.sign(g)*r))

                # rotasi givens
                s = 1
                c = 1
                p = 0
                for k in range(j-1, i-1, -1):
                    f = s*sub[k]
                    b = c*sub[k]
                    if(np.abs(f) > np.abs(g)):
                        c = g/f
                        tau = np.hypot(c, 1)
                        sub[k+1] = f*tau
                        s = 1/tau
                        c *= s
                    else:
                        s = f/g
                        tau = np.hypot(s, 1)
                        sub[k+1] = g*tau
                        c = 1/tau
                        s *= c
                    g = diag[k+1]-p
                    r = 2*b*c+(diag[k]-g)*s
                    p = r*s
                    diag[k+1] = g+p
                    g = r*c-b
                    # eigenvector
                    Q[:,k:k+2] = (Q[:,k:k+2]).dot(np.array([[c,s],[-s,c]]))
                sub[i] = g
                sub[j] = 0
                diag[i] = diag[i]-p
    return diag, Q

def build_decom(A: np.ndarray):
    r = np.float64(A.T).dot(np.float64(A))
    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(1,channel), "Proses Perkalian Matriks Selesai")
    
    # #generate eigenvector with their corresponding eigenval
    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(2,channel), "Menghitung Nilai Eigen")

    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(13,channel), "Menghitung Nilai Eigen")
    
    r_eigval, r_eig = EigenV(r)

    # #shaping matrix
    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(24,channel), "Membentuk Matriks SVD")

    rows, cols = A.shape
    r_sigmum = np.sqrt(np.abs(r_eigval))
    r_sort_pivot = np.argsort(r_sigmum)[::-1]
    sigm = np.pad(np.diag(r_sigmum[r_sort_pivot]), 
        ((0,rows),(0,cols)), mode='constant')[0:rows, 0:cols]

    # sorting right singular         
    r_singular = r_eig.T[r_sort_pivot]
    # sorting & correlate right singular with left singular & dinomalisasi
    l_singular = np.zeros((rows,rows))

    cnt = 0
    i = 0

    for x in r_sigmum:
        # if sendFeedback and cnt % 50 == 0:
        #     state.sendUpdateState(gprocessd(25 + cnt/len(r_sigmum) * 10,channel), "Membentuk Matriks SVD")
        cnt += 1

        if(abs(x)>1e-6 and i<min(l_singular.shape[0],r_singular.shape[0])):
            l_singular[i,:] = (A.dot(r_singular[i,:]))*(1/x)
            i+=1

    
    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(36,channel), "Normalisasi Matriks")

    # l_singular = l_singular.T
    sklearn.preprocessing.normalize(l_singular, norm="l2", axis=1, copy=False)
    l_singular = l_singular.T

    # if sendFeedback:
    #     state.sendUpdateState(gprocessd(37,channel), "SVD Selesai")
    rank = np.sum(sigm>1e-9)
    return l_singular, sigm, r_singular, rank

# %%
# # import scipy
# # im = cv2.imread("../data/instagram.png", cv2.IMREAD_UNCHANGED)
# im = cv2.imread('../data/instagram.png', cv2.IMREAD_UNCHANGED)
# # imC = cv2.applyColorMap(im, cv2.COLORMAP_RAINBOW)
# # print(im)
# Img = np.zeros((1000,1000,4))
# Img[:,:,0] = im[:,:,0]
# Img[:,:,1] = im[:,:,1]
# Img[:,:,2] = im[:,:,2]
# Img[:,:,3] = im[:,:,3]
# cv2.imwrite("../data/image.png", im)
import imageio
import numpy
import argparse
import os
im = imageio.imread("../data/instagram.png")
im = convert
im = imageio.imwrite("../data/image.png", im)
print(im)
# im = Image.open("../data/instagram.png")
# M = np.asarray(im)
# print(M)
# from skimage import io, img_as_float, img_as_uint
# import numpy as np
# im = io.imread("../data/instagram.png", )
# im = img_as_uint(im)
# # im = np.uint8(np.array(im)*255)
# io.imsave("../data/image.png", im)
# print(im)
# N = np.array(im)
# M = np.array(im.getpalette()).reshape((256,3))
# print(np.sum(np.array(im)>0))
# print(M)
# M = M.reshape((256*3))
# # print(M)
# # M = np.array(im.convert("RGBA"))
# im = Image.fromarray(N)
# im.putpalette(M)
# # im = im.convert('P')
# im.save("../data/image.png")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\Users\FIRIZK~1\AppData\Local\Temp/ipykernel_5504/388251247.py in <module>
#      15 import os
#      16 im = imageio.imread("../data/instagram.png")
# ---> 17 im = imageio.imwrite("../data/image.png", im)
#      18 print(im)
#      19 # im = Image.open("../data/instagram.png")
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\imageio\core\functions.py in imwrite(uri, im, format, **kwargs)
#     193
#     194     with imopen()(uri, "wi", format=format) as file:
# --> 195         return file.write(im, **kwargs)
#     196
#     197
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\imageio\core\imopen.py in write(self, image, **kwargs)
#     315         with self.legacy_get_writer(**kwargs) as writer:
#     316             if self._request.mode.image_mode in "iv?":
# --> 317                 writer.append_data(image)
#     318             else:
#     319                 if len(image) == 0:
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\imageio\core\format.py in append_data(self, im, meta)
#     490             im = asarray(im)
#     491             # Call
# --> 492             return self._append_data(im, total_meta)
#     493
#     494         def set_meta_data(self, meta):
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\imageio\plugins\pillow_legacy.py in _append_data(self, im, meta)
#     455             else:
#     456                 im = image_as_uint(im, bitdepth=8)
# --> 457             PillowFormat.Writer._append_data(self, im, meta)
#     458
#     459
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\imageio\plugins\pillow_legacy.py in _append_data(self, im, meta)
#     377             if "bits" in self._meta:
#     378                 img = img.quantize()  # Make it a P image, so bits arg is used
# --> 379             img.save(self._fp, format=self.format.plugin_id, **self._meta)
#     380             save_pillow_close(img)
#     381
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2238
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#    2242             # do what we can to clean up
#
# ~\AppData\Local\Programs\Python\Python38\lib\site-packages\PIL\PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1310                 # don't bother with transparency if it's an RGBA
#    1311                 # and it's in the info dict. It's probably just stale.
# -> 1312                 raise OSError("cannot use transparency for this mode")
#    1313     else:
#    1314         if im.mode == "P" and im.im.getpalettemode() == "RGBA":
#
# OSError: cannot use transparency for this mode

# %%
M = np.array(im.convert("RGBA"))
# M = np.array(im)
p = im.mode
# # print(p)
R = M[:,:,0]
G = M[:,:,1]
B = M[:,:,2]
A = M[:,:,3]
# R, G, B, A = inspectColor(M)
# R, G, B, A = compress_all(R, G, B, A, 50)
# M = np.uint8((np.dstack((R, G, B, A))))
# # x, y, z = M.shape
# # # M = M.reshape(x, y, 4)

# %%
ur, sigmr, vr, rankr = build_decom(R)
ug, sigmg, vg, rankg = build_decom(G)
ub, sigmb, vb, rankb = build_decom(B)
ua, sigma, va, ranka = build_decom(A)
# u, v, w, rankr = build_decom(M)
# rows,cols=R.shape
# ur, sigmr, vr = np.linalg.svd(R)
# sigmr = np.pad(np.diag(sigmr), ((0,rows),(0,cols)), mode='constant')[0:rows, 0:cols]
# ug, sigmg, vg = np.linalg.svd(G)
# sigmg = np.pad(np.diag(sigmg), ((0,rows),(0,cols)), mode='constant')[0:rows, 0:cols]
# ub, sigmb, vb = np.linalg.svd(B)
# sigmb = np.pad(np.diag(sigmb), ((0,rows),(0,cols)), mode='constant')[0:rows, 0:cols]
# ua, sigma, va = np.linalg.svd(A)

# %%
k = 10
print(np.linalg.matrix_rank(R))
print(np.linalg.matrix_rank(G))
print(np.linalg.matrix_rank(B))
print(np.linalg.matrix_rank(A))
print(np.sum(sigmr>1e-6))
k = math.floor(rankr*k/100)
print(k)
# M = (u[:,:k]@(v[:k, :k]@w[:k, :]))
R = (ur[:,:k]@(sigmr[:k, :k]@vr[:k, :]))
G = (ug[:,:k]@(sigmg[:k, :k]@vg[:k, :]))
B = (ub[:,:k]@(sigmb[:k, :k]@vb[:k, :]))
k = math.floor(ranka*k/100)
# A = (ua[:,:k]@(sigma[:k, :k]@va[:k, :]))
A = A
# Out:
# 886
# 886
# 886
# 324
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\FIRIZK~1\AppData\Local\Temp/ipykernel_5504/1978928287.py in <module>
#       4 print(np.linalg.matrix_rank(B))
#       5 print(np.linalg.matrix_rank(A))
# ----> 6 print(np.sum(sigmr>1e-6))
#       7 k = math.floor(rankr*k/100)
#       8 print(k)
#
# NameError: name 'sigmr' is not defined

# %%
# f,g,h = M.shape
res = np.zeros(M.shape).astype("uint8")
# res = np.uint8(M)
# print(np.max(res))
res[:,:,0] = R
res[:,:,1] = G
res[:,:,2] = B
res[:,:,3] = A
# print(res)
# print(M)
# res = (np.dstack((R, G, B, A)))
im = Image.fromarray(res)
# im.putpalette(x)
# im = im.convert("RGBA")
# print(p)
im = im.convert(p)
im.save("../data/image.png")
